# %%
from caption import getCaptions
import torch
import torch.nn.functional as F
import numpy as np
import json
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import skimage.transform
import argparse
# from scipy.misc import imread, imresize
from imageio import imread
from skimage.transform import resize
from PIL import Image

# %%
image_path='/data/dataset/flickr-8k/Flickr_Data/Flickr_Data/Images/3387661249_33e5ba0bc5.jpg'
image = Image.open(image_path)
image = image.resize([14 * 24, 14 * 24], Image.LANCZOS)
plt.imshow(image)

# %%
getCaptions(image_path)
# Out:
# hello tensor([0, 0, 0, 0, 0], device='cuda:0')
# hello tensor([0, 0, 0, 0, 0], device='cuda:0')
# hello tensor([0, 0, 0, 4, 0], device='cuda:0')
# hello tensor([0, 2, 4, 3, 0], device='cuda:0')
# hello tensor([0, 3, 0, 0, 0], device='cuda:0')
# hello tensor([3, 2, 0, 4, 4], device='cuda:0')
# hello tensor([1, 0, 3, 2, 0], device='cuda:0')
# hello tensor([0, 1, 3, 2, 2], device='cuda:0')
# hello tensor([0, 0, 0, 1, 1], device='cuda:0')
# hello tensor([2, 0, 1, 3, 2], device='cuda:0')
# hello tensor([0, 1, 3, 0, 1], device='cuda:0')
# hello tensor([0, 0, 1, 0, 2], device='cuda:0')
# hello tensor([0, 0, 1, 0, 0], device='cuda:0')
# hello tensor([2, 3, 1, 0], device='cuda:0')
# hello tensor([2, 0, 3, 0], device='cuda:0')
# hello tensor([1, 1, 2], device='cuda:0')
# hello tensor([0, 0, 2], device='cuda:0')
# hello tensor([0, 1], device='cuda:0')
# a ['<start>', 'a', 'man', 'in', 'a', 'white', 'shirt', 'and', 'a', 'black', 'and', 'white', 'dog', '<end>']
